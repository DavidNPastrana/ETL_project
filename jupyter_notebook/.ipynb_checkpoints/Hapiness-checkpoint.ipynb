# %% [markdown]
# # Data Cleaning: happiness_project

# %%
import pandas as pd
import numpy as np
import re

import requests as req
from bs4 import BeautifulSoup as bs

import json

# %%
pd.set_option('display.max_columns', None)  # display all columns
pd.set_option('display.max_rows', None)  # display all rows

# %%
# Download the CSV file containing the happiness data for further analysis.

happiness_ori = pd.read_csv("/Users/david/Desktop/IronHack/Projects/ETL_project_happiness/data/raw_data/happiness_raw.csv")

# %% [markdown]
# ## Initial data exploration

# %%
happiness_ori.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %% [markdown]
# ## Data cleaning and transformation

# %%
# Create a copy of the original dataframe "happiness_ori"
# Make names lowercase
# Make names snake case

happiness = happiness_ori

happiness.columns = happiness.columns.str.lower()

happiness.columns = happiness.columns.str.replace(" ","_")

happiness.head()
# Out:
#    overall_rank country_or_region  score  gdp_per_capita  social_support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    perceptions_of_corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
happiness.shape
# Out:
# (156, 9)

# %%
# Sort the values alphabetically by the country or region name.

happiness = happiness.sort_values("country_or_region")

happiness.head()
# Out:
#      overall_rank country_or_region  score  gdp_per_capita  social_support  \
# 153           154       Afghanistan  3.203           0.350           0.517
# 106           107           Albania  4.719           0.947           0.848
# 87             88           Algeria  5.211           1.002           1.160
# 46             47         Argentina  6.086           1.092           1.432
# 115           116           Armenia  4.559           0.850           1.055
#
#      healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 153                    0.361                         0.000       0.158
# 106                    0.874                         0.383       0.178
# 87                     0.785                         0.086       0.073
# 46                     0.881                         0.471       0.066
# 115                    0.815                         0.283       0.095
#
#      perceptions_of_corruption
# 153                      0.025
# 106                      0.027
# 87                       0.114
# 46                       0.050
# 115                      0.064

# %%
# Create a column for the country or region ID.

happiness["overall_rank"] = range(1, len(happiness["country_or_region"]) + 1)

happiness.rename(columns={"overall_rank": "country_or_region_id"}, inplace=True)

happiness.head()
# Out:
#      country_or_region_id country_or_region  score  gdp_per_capita  \
# 153                     1       Afghanistan  3.203           0.350
# 106                     2           Albania  4.719           0.947
# 87                      3           Algeria  5.211           1.002
# 46                      4         Argentina  6.086           1.092
# 115                     5           Armenia  4.559           0.850
#
#      social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 153           0.517                    0.361                         0.000
# 106           0.848                    0.874                         0.383
# 87            1.160                    0.785                         0.086
# 46            1.432                    0.881                         0.471
# 115           1.055                    0.815                         0.283
#
#      generosity  perceptions_of_corruption
# 153       0.158                      0.025
# 106       0.178                      0.027
# 87        0.073                      0.114
# 46        0.066                      0.050
# 115       0.095                      0.064

# %%
# Select only 3 columns from the dataframe "happiness" that we are interested in: country_or_region_id, country_or_region and hapiness score.

happiness = happiness[["country_or_region_id","country_or_region","score"]]

happiness = happiness.rename(columns={"score": "happiness_score"})

happiness.head()
# Out:
#      country_or_region_id country_or_region  happiness_score
# 153                     1       Afghanistan            3.203
# 106                     2           Albania            4.719
# 87                      3           Algeria            5.211
# 46                      4         Argentina            6.086
# 115                     5           Armenia            4.559

# %%
happiness.shape
# Out:
# (156, 3)

# %% [markdown]
# ## Scrape additional information from the web: Global Peace Index. Perform initial data exploration and data cleaning on the scraped data.
#
# You can find the index [here](https://en.wikipedia.org/wiki/Global_Peace_Index)

# %%
url = 'https://en.wikipedia.org/wiki/Global_Peace_Index'

html = req.get(url).content  

html[:10]
# Out:
# b'<!DOCTYPE '

# %%
soup = bs(html, 'html.parser')

# %%
# global peace index

table = soup.find_all('table')

# Omit displaying table[2] due to its lengthy output.

# %%
# Rename the data frame to "peace_index"
# Perform initial data exploration on the "peace_index" DataFrame

table_str = str(table[2])

peace_index = pd.read_html(table_str)[0]

peace_index.head()
# Out:
#        Country 2019[10]        2018[11]        2017[12]        2016[13]  \
#        Country     Rank  Score     Rank  Score     Rank  Score     Rank
# 0   Luxembourg        —      —        —      —        —      —        —
# 1      Iceland        1  1.072        1  1.096        1  1.111        1
# 2  New Zealand        2  1.221        2  1.192        2  1.241        4
# 3     Portugal        3  1.274        4  1.318        3  1.258        5
# 4      Austria        4  1.291        3  1.274        4  1.265        3
#
#          2015[14]        2014[15]        2013[16]        2012[17]         \
#    Score     Rank  Score     Rank  Score     Rank  Score     Rank  Score
# 0      —        —      —        —      —        —      —        —      —
# 1  1.192        1  1.148        1  1.189        1  1.162        1  1.113
# 2  1.287        4  1.221        4  1.236        3  1.237       2=  1.239
# 3  1.356       11  1.344       18  1.425       18  1.467       16  1.470
# 4  1.278        3  1.198        3  1.200        4  1.250       6=  1.328
#
#   2011[18]        2010[19]
#       Rank  Score     Rank  Score
# 0        —      —       7=  1.341
# 1        1  1.148        2  1.212
# 2        2  1.279        1  1.188
# 3       17  1.453       13  1.366
# 4        6  1.337        4  1.290

# %%
peace_index.columns
# Out:
# MultiIndex([( 'Country', 'Country'),
#             ('2019[10]',    'Rank'),
#             ('2019[10]',   'Score'),
#             ('2018[11]',    'Rank'),
#             ('2018[11]',   'Score'),
#             ('2017[12]',    'Rank'),
#             ('2017[12]',   'Score'),
#             ('2016[13]',    'Rank'),
#             ('2016[13]',   'Score'),
#             ('2015[14]',    'Rank'),
#             ('2015[14]',   'Score'),
#             ('2014[15]',    'Rank'),
#             ('2014[15]',   'Score'),
#             ('2013[16]',    'Rank'),
#             ('2013[16]',   'Score'),
#             ('2012[17]',    'Rank'),
#             ('2012[17]',   'Score'),
#             ('2011[18]',    'Rank'),
#             ('2011[18]',   'Score'),
#             ('2010[19]',    'Rank'),
#             ('2010[19]',   'Score')],
#            )

# %%
# Make names snake case

peace_index.columns = peace_index.columns.map('_'.join)

peace_index.head()
# Out:
#   Country_Country 2019[10]_Rank 2019[10]_Score 2018[11]_Rank 2018[11]_Score  \
# 0      Luxembourg             —              —             —              —
# 1         Iceland             1          1.072             1          1.096
# 2     New Zealand             2          1.221             2          1.192
# 3        Portugal             3          1.274             4          1.318
# 4         Austria             4          1.291             3          1.274
#
#   2017[12]_Rank 2017[12]_Score 2016[13]_Rank 2016[13]_Score 2015[14]_Rank  \
# 0             —              —             —              —             —
# 1             1          1.111             1          1.192             1
# 2             2          1.241             4          1.287             4
# 3             3          1.258             5          1.356            11
# 4             4          1.265             3          1.278             3
#
#   2015[14]_Score 2014[15]_Rank 2014[15]_Score 2013[16]_Rank 2013[16]_Score  \
# 0              —             —              —             —              —
# 1          1.148             1          1.189             1          1.162
# 2          1.221             4          1.236             3          1.237
# 3          1.344            18          1.425            18          1.467
# 4          1.198             3          1.200             4          1.250
#
#   2012[17]_Rank 2012[17]_Score 2011[18]_Rank 2011[18]_Score 2010[19]_Rank  \
# 0             —              —             —              —            7=
# 1             1          1.113             1          1.148             2
# 2            2=          1.239             2          1.279             1
# 3            16          1.470            17          1.453            13
# 4            6=          1.328             6          1.337             4
#
#   2010[19]_Score
# 0          1.341
# 1          1.212
# 2          1.188
# 3          1.366
# 4          1.290

# %%
peace_index.shape
# Out:
# (164, 21)

# %%
# Select only 2 columns from the dataframe "peace_index" that we are interested in: Country_Country and peace_index.

peace_index = peace_index[['Country_Country', '2019[10]_Score']]

peace_index = peace_index.rename(columns={"2019[10]_Score": "peace_index"})

peace_index.head()
# Out:
#   Country_Country peace_index
# 0      Luxembourg           —
# 1         Iceland       1.072
# 2     New Zealand       1.221
# 3        Portugal       1.274
# 4         Austria       1.291

# %%
# Remove the first row since it does not contain any information

peace_index = peace_index.drop(index=0)

# %%
peace_index.isnull().sum()
# Out:
# Country_Country    0
# peace_index        0
# dtype: int64

# %%
peace_index.head()
# Out:
#   Country_Country peace_index
# 1         Iceland       1.072
# 2     New Zealand       1.221
# 3        Portugal       1.274
# 4         Austria       1.291
# 5         Denmark       1.316

# %%
# Merge the column "peace_index" into the DataFrame "happiness".
# Rename the DataFrame "happiness" to "happiness_with_peace_index".

happiness_with_peace_index = happiness.merge(peace_index, left_on='country_or_region', right_on='Country_Country', how='left')

happiness_with_peace_index = happiness_with_peace_index.drop(columns="Country_Country")

happiness_with_peace_index.head()
# Out:
#    country_or_region_id country_or_region  happiness_score peace_index
# 0                     1       Afghanistan            3.203       3.574
# 1                     2           Albania            4.719       1.821
# 2                     3           Algeria            5.211       2.219
# 3                     4         Argentina            6.086       1.989
# 4                     5           Armenia            4.559       2.294

# %%
happiness_with_peace_index.shape
# Out:
# (156, 4)

# %%
happiness_with_peace_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156 entries, 0 to 155
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country_or_region_id  156 non-null    int64
#  1   country_or_region     156 non-null    object
#  2   happiness_score       156 non-null    float64
#  3   peace_index           143 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.1+ KB

# %% [markdown]
# ## Scrape additional information from the web: Number of religious people by country. Perform initial data exploration and data cleaning on the scraped data.

# %%
url = 'https://ceoworld.biz/2020/05/16/revealed-the-worlds-most-and-least-religious-countries-based-on-religious-beliefs-2020/'

html = req.get(url).content   # o .text

html[:10]
# Out:
# b'<!DOCTYPE '

# %%
soup = bs(html, 'html.parser')

table = soup.find_all('table')

# Omit displaying table[0] due to its lengthy output.

# %%
# Perform initial data exploration on the web-scraped data and name the DataFrame "religious_people".

table_str = str(table[0])

religious_people = pd.read_html(table_str)[0]

religious_people.head()
# Out:
#    Rank     Country  Feel Religious
# 0     1     Somalia            99.8
# 1     2       Niger            99.7
# 2     3  Bangladesh            99.5
# 3     4    Ethiopia            99.3
# 4     5       Yemen            99.1

# %%
# Merge the column "feel_religious" into the dataframe "happiness_with_peace_index".
# Rename the dataframe "happiness_with_peace_index" to "happiness_with_religious".

happiness_with_religious = pd.DataFrame(happiness_with_peace_index.merge(religious_people, left_on='country_or_region', right_on='Country', how='left'))

happiness_with_religious.head()
# Out:
#    country_or_region_id country_or_region  happiness_score peace_index   Rank  \
# 0                     1       Afghanistan            3.203       3.574   16.0
# 1                     2           Albania            4.719       1.821  125.0
# 2                     3           Algeria            5.211       2.219   34.0
# 3                     4         Argentina            6.086       1.989  105.0
# 4                     5           Armenia            4.559       2.294   91.0
#
#        Country  Feel Religious
# 0  Afghanistan            97.0
# 1      Albania            39.0
# 2      Algeria            95.0
# 3    Argentina            65.0
# 4      Armenia            73.0

# %%
# Make names snake case.
# Delete the columns "Country" and "Rank".

happiness_with_religious = happiness_with_religious.rename(columns={"Feel Religious": "feel_religious"})

happiness_with_religious = happiness_with_religious.drop(["Country", "Rank"], axis=1)

happiness_with_religious.head()
# Out:
#    country_or_region_id country_or_region  happiness_score peace_index  \
# 0                     1       Afghanistan            3.203       3.574
# 1                     2           Albania            4.719       1.821
# 2                     3           Algeria            5.211       2.219
# 3                     4         Argentina            6.086       1.989
# 4                     5           Armenia            4.559       2.294
#
#    feel_religious
# 0            97.0
# 1            39.0
# 2            95.0
# 3            65.0
# 4            73.0

# %%
# Rename the dataframe "happiness_with_religious" to "happiness"

happiness = happiness_with_religious

# %%
happiness["peace_index"] = happiness["peace_index"].astype(float)

happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156 entries, 0 to 155
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country_or_region_id  156 non-null    int64
#  1   country_or_region     156 non-null    object
#  2   happiness_score       156 non-null    float64
#  3   peace_index           143 non-null    float64
#  4   feel_religious        138 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 7.3+ KB

# %%
# Create 3 new columns with descriptive information derived from the numeric columns.

happiness["happiness_score_category"] = pd.qcut(happiness["happiness_score"], q=[0, 0.25, 0.5, 0.75, 1], labels=["sad", "not_happy", "happy", "very_happy"])

happiness["peace_index_category"] = pd.qcut(happiness["peace_index"], q=[0, 0.25, 0.5, 0.75, 1], labels=["very_safe", "safe", "not_safe", "dangerous"])

happiness["feel_religious_category"] = pd.qcut(happiness["feel_religious"], q=[0, 0.25, 0.5, 0.75, 1], labels=["not_religious", "slightly_religious", "religious", "very_religious"])


happiness.head()
# Out:
#    country_or_region_id country_or_region  happiness_score  peace_index  \
# 0                     1       Afghanistan            3.203        3.574
# 1                     2           Albania            4.719        1.821
# 2                     3           Algeria            5.211        2.219
# 3                     4         Argentina            6.086        1.989
# 4                     5           Armenia            4.559        2.294
#
#    feel_religious happiness_score_category peace_index_category  \
# 0            97.0                      sad            dangerous
# 1            39.0                not_happy                 safe
# 2            95.0                not_happy             not_safe
# 3            65.0                    happy                 safe
# 4            73.0                not_happy             not_safe
#
#   feel_religious_category
# 0          very_religious
# 1           not_religious
# 2          very_religious
# 3      slightly_religious
# 4      slightly_religious

# %%
new_column_order = ['country_or_region_id', 'country_or_region', 'happiness_score', 'happiness_score_category', 'peace_index', 'peace_index_category', 'feel_religious', "feel_religious_category"]

happiness = happiness[new_column_order]

happiness.head()
# Out:
#    country_or_region_id country_or_region  happiness_score  \
# 0                     1       Afghanistan            3.203
# 1                     2           Albania            4.719
# 2                     3           Algeria            5.211
# 3                     4         Argentina            6.086
# 4                     5           Armenia            4.559
#
#   happiness_score_category  peace_index peace_index_category  feel_religious  \
# 0                      sad        3.574            dangerous            97.0
# 1                not_happy        1.821                 safe            39.0
# 2                not_happy        2.219             not_safe            95.0
# 3                    happy        1.989                 safe            65.0
# 4                not_happy        2.294             not_safe            73.0
#
#   feel_religious_category
# 0          very_religious
# 1           not_religious
# 2          very_religious
# 3      slightly_religious
# 4      slightly_religious

# %%
happiness.shape
# Out:
# (156, 8)

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156 entries, 0 to 155
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country_or_region_id      156 non-null    int64
#  1   country_or_region         156 non-null    object
#  2   happiness_score           156 non-null    float64
#  3   happiness_score_category  156 non-null    category
#  4   peace_index               143 non-null    float64
#  5   peace_index_category      143 non-null    category
#  6   feel_religious            138 non-null    float64
#  7   feel_religious_category   138 non-null    category
# dtypes: category(3), float64(3), int64(1), object(1)
# memory usage: 8.4+ KB

# %%
happiness.describe()
# Out:
#        country_or_region_id  happiness_score  peace_index  feel_religious
# count            156.000000       156.000000   143.000000      138.000000
# mean              78.500000         5.407096     2.076622       72.378261
# std               45.177428         1.113120     0.522983       25.489662
# min                1.000000         2.853000     1.072000        7.000000
# 25%               39.750000         4.544500     1.726000       49.250000
# 50%               78.500000         5.379500     2.012000       83.000000
# 75%              117.250000         6.184500     2.337000       94.000000
# max              156.000000         7.769000     3.574000       99.800000

# %%
# Fill null values with the mean in numeric columns.

# Fill null values with "unknown" in the categorical columns.

happiness["peace_index"] = happiness["peace_index"].fillna(np.mean(happiness["peace_index"]))

happiness["feel_religious"] = happiness["feel_religious"].fillna(np.mean(happiness["feel_religious"]))

happiness["peace_index_category"] = happiness["peace_index_category"].cat.add_categories("unknown")

happiness["feel_religious_category"] = happiness["feel_religious_category"].cat.add_categories("unknown")

happiness["peace_index_category"].fillna("unknown", inplace=True)

happiness["feel_religious_category"].fillna("unknown",inplace=True)

happiness.head()
# Out:
#    country_or_region_id country_or_region  happiness_score  \
# 0                     1       Afghanistan            3.203
# 1                     2           Albania            4.719
# 2                     3           Algeria            5.211
# 3                     4         Argentina            6.086
# 4                     5           Armenia            4.559
#
#   happiness_score_category  peace_index peace_index_category  feel_religious  \
# 0                      sad        3.574            dangerous            97.0
# 1                not_happy        1.821                 safe            39.0
# 2                not_happy        2.219             not_safe            95.0
# 3                    happy        1.989                 safe            65.0
# 4                not_happy        2.294             not_safe            73.0
#
#   feel_religious_category
# 0          very_religious
# 1           not_religious
# 2          very_religious
# 3      slightly_religious
# 4      slightly_religious

# %%
happiness.isnull().sum()
# Out:
# country_or_region_id        0
# country_or_region           0
# happiness_score             0
# happiness_score_category    0
# peace_index                 0
# peace_index_category        0
# feel_religious              0
# feel_religious_category     0
# dtype: int64

# %%
# Round the values and align the number of decimal points to prepare the data for MySQL Workbench

happiness["happiness_score"] = happiness["happiness_score"].round(2)

happiness["peace_index"] = happiness["peace_index"].round(2)

happiness["feel_religious"] = happiness["feel_religious"].round(0)

happiness
# Out:
#      country_or_region_id         country_or_region  happiness_score  \
# 0                       1               Afghanistan             3.20
# 1                       2                   Albania             4.72
# 2                       3                   Algeria             5.21
# 3                       4                 Argentina             6.09
# 4                       5                   Armenia             4.56
# 5                       6                 Australia             7.23
# 6                       7                   Austria             7.25
# 7                       8                Azerbaijan             5.21
# 8                       9                   Bahrain             6.20
# 9                      10                Bangladesh             4.46
# 10                     11                   Belarus             5.32
# 11                     12                   Belgium             6.92
# 12                     13                     Benin             4.88
# 13                     14                    Bhutan             5.08
# 14                     15                   Bolivia             5.78
# 15                     16    Bosnia and Herzegovina             5.39
# 16                     17                  Botswana             3.49
# 17                     18                    Brazil             6.30
# 18                     19                  Bulgaria             5.01
# 19                     20              Burkina Faso             4.59
# 20                     21                   Burundi             3.78
# 21                     22                  Cambodia             4.70
# 22                     23                  Cameroon             5.04
# 23                     24                    Canada             7.28
# 24                     25  Central African Republic             3.08
# 25                     26                      Chad             4.35
# 26                     27                     Chile             6.44
# 27                     28                     China             5.19
# 28                     29                  Colombia             6.12
# 29                     30                   Comoros             3.97
# 30                     31       Congo (Brazzaville)             4.81
# 31                     32          Congo (Kinshasa)             4.42
# 32                     33                Costa Rica             7.17
# 33                     34                   Croatia             5.43
# 34                     35                    Cyprus             6.05
# 35                     36            Czech Republic             6.85
# 36                     37                   Denmark             7.60
# 37                     38        Dominican Republic             5.42
# 38                     39                   Ecuador             6.03
# 39                     40                     Egypt             4.17
# 40                     41               El Salvador             6.25
# 41                     42                   Estonia             5.89
# 42                     43                  Ethiopia             4.29
# 43                     44                   Finland             7.77
# 44                     45                    France             6.59
# 45                     46                     Gabon             4.80
# 46                     47                    Gambia             4.52
# 47                     48                   Georgia             4.52
# 48                     49                   Germany             6.98
# 49                     50                     Ghana             5.00
# 50                     51                    Greece             5.29
# 51                     52                 Guatemala             6.44
# 52                     53                    Guinea             4.53
# 53                     54                     Haiti             3.60
# 54                     55                  Honduras             5.86
# 55                     56                 Hong Kong             5.43
# 56                     57                   Hungary             5.76
# 57                     58                   Iceland             7.49
# 58                     59                     India             4.01
# 59                     60                 Indonesia             5.19
# 60                     61                      Iran             4.55
# 61                     62                      Iraq             4.44
# 62                     63                   Ireland             7.02
# 63                     64                    Israel             7.14
# 64                     65                     Italy             6.22
# 65                     66               Ivory Coast             4.94
# 66                     67                   Jamaica             5.89
# 67                     68                     Japan             5.89
# 68                     69                    Jordan             4.91
# 69                     70                Kazakhstan             5.81
# 70                     71                     Kenya             4.51
# 71                     72                    Kosovo             6.10
# 72                     73                    Kuwait             6.02
# 73                     74                Kyrgyzstan             5.26
# 74                     75                      Laos             4.80
# 75                     76                    Latvia             5.94
# 76                     77                   Lebanon             5.20
# 77                     78                   Lesotho             3.80
# 78                     79                   Liberia             3.98
# 79                     80                     Libya             5.52
# 80                     81                 Lithuania             6.15
# 81                     82                Luxembourg             7.09
# 82                     83                Madagascar             3.93
# 83                     84                    Malawi             3.41
# 84                     85                  Malaysia             5.34
# 85                     86                      Mali             4.39
# 86                     87                     Malta             6.73
# 87                     88                Mauritania             4.49
# 88                     89                 Mauritius             5.89
# 89                     90                    Mexico             6.60
# 90                     91                   Moldova             5.53
# 91                     92                  Mongolia             5.28
# 92                     93                Montenegro             5.52
# 93                     94                   Morocco             5.21
# 94                     95                Mozambique             4.47
# 95                     96                   Myanmar             4.36
# 96                     97                   Namibia             4.64
# 97                     98                     Nepal             4.91
# 98                     99               Netherlands             7.49
# 99                    100               New Zealand             7.31
# 100                   101                 Nicaragua             6.10
# 101                   102                     Niger             4.63
# 102                   103                   Nigeria             5.26
# 103                   104           North Macedonia             5.27
# 104                   105           Northern Cyprus             5.72
# 105                   106                    Norway             7.55
# 106                   107                  Pakistan             5.65
# 107                   108   Palestinian Territories             4.70
# 108                   109                    Panama             6.32
# 109                   110                  Paraguay             5.74
# 110                   111                      Peru             5.70
# 111                   112               Philippines             5.63
# 112                   113                    Poland             6.18
# 113                   114                  Portugal             5.69
# 114                   115                     Qatar             6.37
# 115                   116                   Romania             6.07
# 116                   117                    Russia             5.65
# 117                   118                    Rwanda             3.33
# 118                   119              Saudi Arabia             6.38
# 119                   120                   Senegal             4.68
# 120                   121                    Serbia             5.60
# 121                   122              Sierra Leone             4.37
# 122                   123                 Singapore             6.26
# 123                   124                  Slovakia             6.20
# 124                   125                  Slovenia             6.12
# 125                   126                   Somalia             4.67
# 126                   127              South Africa             4.72
# 127                   128               South Korea             5.90
# 128                   129               South Sudan             2.85
# 129                   130                     Spain             6.35
# 130                   131                 Sri Lanka             4.37
# 131                   132                 Swaziland             4.21
# 132                   133                    Sweden             7.34
# 133                   134               Switzerland             7.48
# 134                   135                     Syria             3.46
# 135                   136                    Taiwan             6.45
# 136                   137                Tajikistan             5.47
# 137                   138                  Tanzania             3.23
# 138                   139                  Thailand             6.01
# 139                   140                      Togo             4.08
# 140                   141         Trinidad & Tobago             6.19
# 141                   142                   Tunisia             4.46
# 142                   143                    Turkey             5.37
# 143                   144              Turkmenistan             5.25
# 144                   145                    Uganda             4.19
# 145                   146                   Ukraine             4.33
# 146                   147      United Arab Emirates             6.82
# 147                   148            United Kingdom             7.05
# 148                   149             United States             6.89
# 149                   150                   Uruguay             6.29
# 150                   151                Uzbekistan             6.17
# 151                   152                 Venezuela             4.71
# 152                   153                   Vietnam             5.18
# 153                   154                     Yemen             3.38
# 154                   155                    Zambia             4.11
# 155                   156                  Zimbabwe             3.66
#
#     happiness_score_category  peace_index peace_index_category  \
# 0                        sad         3.57            dangerous
# 1                  not_happy         1.82                 safe
# 2                  not_happy         2.22             not_safe
# 3                      happy         1.99                 safe
# 4                  not_happy         2.29             not_safe
# 5                 very_happy         1.42            very_safe
# 6                 very_happy         1.29            very_safe
# 7                  not_happy         2.42            dangerous
# 8                 very_happy         2.36            dangerous
# 9                        sad         2.13             not_safe
# 10                 not_happy         2.12             not_safe
# 11                very_happy         1.53            very_safe
# 12                 not_happy         1.99                 safe
# 13                 not_happy         1.51            very_safe
# 14                     happy         2.04             not_safe
# 15                     happy         2.02             not_safe
# 16                       sad         1.68            very_safe
# 17                very_happy         2.27             not_safe
# 18                 not_happy         1.61            very_safe
# 19                 not_happy         2.18             not_safe
# 20                       sad         2.52            dangerous
# 21                 not_happy         2.07             not_safe
# 22                 not_happy         2.54            dangerous
# 23                very_happy         1.33            very_safe
# 24                       sad         3.30            dangerous
# 25                       sad         2.52            dangerous
# 26                very_happy         1.63            very_safe
# 27                 not_happy         2.22             not_safe
# 28                     happy         2.66            dangerous
# 29                       sad         2.08              unknown
# 30                 not_happy         2.08              unknown
# 31                       sad         2.08              unknown
# 32                very_happy         1.71            very_safe
# 33                     happy         1.64            very_safe
# 34                     happy         1.91                 safe
# 35                very_happy         1.38            very_safe
# 36                very_happy         1.32            very_safe
# 37                     happy         2.04             not_safe
# 38                     happy         1.98                 safe
# 39                       sad         2.52            dangerous
# 40                very_happy         2.26             not_safe
# 41                     happy         1.73                 safe
# 42                       sad         2.43            dangerous
# 43                very_happy         1.49            very_safe
# 44                very_happy         1.89                 safe
# 45                 not_happy         2.11             not_safe
# 46                       sad         2.08              unknown
# 47                       sad         2.12             not_safe
# 48                very_happy         1.55            very_safe
# 49                 not_happy         1.80                 safe
# 50                 not_happy         1.93                 safe
# 51                very_happy         2.26             not_safe
# 52                       sad         2.12             not_safe
# 53                       sad         2.05             not_safe
# 54                     happy         2.34            dangerous
# 55                     happy         2.08              unknown
# 56                     happy         1.54            very_safe
# 57                very_happy         1.07            very_safe
# 58                       sad         2.60            dangerous
# 59                 not_happy         1.78                 safe
# 60                 not_happy         2.54            dangerous
# 61                       sad         3.37            dangerous
# 62                very_happy         1.39            very_safe
# 63                very_happy         2.74            dangerous
# 64                very_happy         1.75                 safe
# 65                 not_happy         2.08              unknown
# 66                     happy         2.04             not_safe
# 67                     happy         1.37            very_safe
# 68                 not_happy         2.01                 safe
# 69                     happy         1.93                 safe
# 70                       sad         2.30             not_safe
# 71                     happy         2.05             not_safe
# 72                     happy         1.79                 safe
# 73                 not_happy         2.08              unknown
# 74                 not_happy         1.80                 safe
# 75                     happy         1.72            very_safe
# 76                 not_happy         2.80            dangerous
# 77                       sad         2.17             not_safe
# 78                       sad         1.89                 safe
# 79                     happy         3.28            dangerous
# 80                     happy         1.73                 safe
# 81                very_happy         2.08              unknown
# 82                       sad         1.87                 safe
# 83                       sad         1.78                 safe
# 84                 not_happy         1.53            very_safe
# 85                       sad         2.71            dangerous
# 86                very_happy         2.08              unknown
# 87                       sad         2.33             not_safe
# 88                     happy         1.56            very_safe
# 89                very_happy         2.60            dangerous
# 90                     happy         1.95                 safe
# 91                 not_happy         1.79                 safe
# 92                     happy         1.94                 safe
# 93                 not_happy         2.07             not_safe
# 94                       sad         2.10             not_safe
# 95                       sad         2.39            dangerous
# 96                 not_happy         1.89                 safe
# 97                 not_happy         2.00                 safe
# 98                very_happy         1.53            very_safe
# 99                very_happy         1.22            very_safe
# 100                    happy         2.31             not_safe
# 101                not_happy         2.39            dangerous
# 102                not_happy         2.90            dangerous
# 103                not_happy         1.93                 safe
# 104                    happy         2.08              unknown
# 105               very_happy         1.54            very_safe
# 106                    happy         3.07            dangerous
# 107                not_happy         2.08              unknown
# 108               very_happy         1.80                 safe
# 109                    happy         2.06             not_safe
# 110                    happy         2.02             not_safe
# 111                    happy         2.52            dangerous
# 112                    happy         1.65            very_safe
# 113                    happy         1.27            very_safe
# 114               very_happy         1.70            very_safe
# 115                    happy         1.61            very_safe
# 116                    happy         3.09            dangerous
# 117                      sad         2.01             not_safe
# 118               very_happy         2.41            dangerous
# 119                not_happy         1.88                 safe
# 120                    happy         1.81                 safe
# 121                      sad         1.82                 safe
# 122               very_happy         1.35            very_safe
# 123               very_happy         1.55            very_safe
# 124                    happy         1.36            very_safe
# 125                not_happy         3.30            dangerous
# 126                not_happy         2.40            dangerous
# 127                    happy         1.87                 safe
# 128                      sad         3.53            dangerous
# 129               very_happy         1.70            very_safe
# 130                      sad         1.99                 safe
# 131                      sad         2.08              unknown
# 132               very_happy         1.53            very_safe
# 133               very_happy         1.38            very_safe
# 134                      sad         3.57            dangerous
# 135               very_happy         1.72            very_safe
# 136                    happy         2.20             not_safe
# 137                      sad         1.86                 safe
# 138                    happy         2.28             not_safe
# 139                      sad         2.20             not_safe
# 140               very_happy         2.08              unknown
# 141                      sad         2.04             not_safe
# 142                not_happy         3.02            dangerous
# 143                not_happy         2.26             not_safe
# 144                      sad         2.20             not_safe
# 145                      sad         2.95            dangerous
# 146               very_happy         1.85                 safe
# 147               very_happy         1.80                 safe
# 148               very_happy         2.40            dangerous
# 149               very_happy         1.71            very_safe
# 150                    happy         2.17             not_safe
# 151                not_happy         2.67            dangerous
# 152                not_happy         1.88                 safe
# 153                      sad         3.41            dangerous
# 154                      sad         1.80                 safe
# 155                      sad         2.46            dangerous
#
#      feel_religious feel_religious_category
# 0              97.0          very_religious
# 1              39.0           not_religious
# 2              95.0          very_religious
# 3              65.0      slightly_religious
# 4              73.0      slightly_religious
# 5              32.0           not_religious
# 6              55.0      slightly_religious
# 7              50.0      slightly_religious
# 8              94.0               religious
# 9             100.0          very_religious
# 10             34.0           not_religious
# 11             33.0           not_religious
# 12             93.0               religious
# 13             72.0                 unknown
# 14             89.0               religious
# 15             77.0      slightly_religious
# 16             77.0      slightly_religious
# 17             87.0               religious
# 18             34.0           not_religious
# 19             88.0               religious
# 20             98.0          very_religious
# 21             96.0          very_religious
# 22             96.0          very_religious
# 23             42.0           not_religious
# 24             94.0               religious
# 25             95.0          very_religious
# 26             70.0      slightly_religious
# 27              7.0           not_religious
# 28             83.0      slightly_religious
# 29             97.0          very_religious
# 30             72.0                 unknown
# 31             72.0                 unknown
# 32             79.0      slightly_religious
# 33             70.0      slightly_religious
# 34             75.0      slightly_religious
# 35             21.0           not_religious
# 36             19.0           not_religious
# 37             87.0               religious
# 38             82.0      slightly_religious
# 39             97.0          very_religious
# 40             83.0      slightly_religious
# 41             16.0           not_religious
# 42             99.0          very_religious
# 43             28.0           not_religious
# 44             30.0           not_religious
# 45             72.0                 unknown
# 46             72.0                 unknown
# 47             81.0      slightly_religious
# 48             40.0           not_religious
# 49             95.0          very_religious
# 50             71.0      slightly_religious
# 51             88.0               religious
# 52             97.0          very_religious
# 53             75.0      slightly_religious
# 54             84.0               religious
# 55             24.0           not_religious
# 56             39.0           not_religious
# 57             72.0                 unknown
# 58             90.0               religious
# 59             99.0          very_religious
# 60             73.0      slightly_religious
# 61             84.0               religious
# 62             54.0      slightly_religious
# 63             51.0      slightly_religious
# 64             72.0      slightly_religious
# 65             88.0               religious
# 66             70.0      slightly_religious
# 67             24.0           not_religious
# 68             96.0          very_religious
# 69             43.0           not_religious
# 70             94.0               religious
# 71             72.0                 unknown
# 72             91.0               religious
# 73             72.0      slightly_religious
# 74             97.0          very_religious
# 75             39.0           not_religious
# 76             87.0               religious
# 77             72.0                 unknown
# 78             94.0               religious
# 79             72.0                 unknown
# 80             42.0           not_religious
# 81             39.0           not_religious
# 82             93.0               religious
# 83             99.0          very_religious
# 84             96.0          very_religious
# 85             95.0          very_religious
# 86             86.0               religious
# 87             98.0          very_religious
# 88             72.0                 unknown
# 89             73.0      slightly_religious
# 90             72.0      slightly_religious
# 91             72.0                 unknown
# 92             71.0      slightly_religious
# 93             97.0          very_religious
# 94             86.0               religious
# 95             97.0          very_religious
# 96             92.0               religious
# 97             93.0               religious
# 98             33.0           not_religious
# 99             33.0           not_religious
# 100            84.0               religious
# 101           100.0          very_religious
# 102            96.0          very_religious
# 103            72.0                 unknown
# 104            72.0                 unknown
# 105            21.0           not_religious
# 106            92.0               religious
# 107            72.0                 unknown
# 108            88.0               religious
# 109            92.0               religious
# 110            84.0               religious
# 111            96.0          very_religious
# 112            75.0      slightly_religious
# 113            72.0      slightly_religious
# 114            95.0          very_religious
# 115            84.0               religious
# 116            34.0           not_religious
# 117            95.0          very_religious
# 118            93.0               religious
# 119            96.0          very_religious
# 120            54.0      slightly_religious
# 121            72.0                 unknown
# 122            70.0      slightly_religious
# 123            47.0           not_religious
# 124            47.0           not_religious
# 125           100.0          very_religious
# 126            85.0               religious
# 127            43.0           not_religious
# 128            72.0                 unknown
# 129            49.0           not_religious
# 130            99.0          very_religious
# 131            72.0                 unknown
# 132            17.0           not_religious
# 133            41.0           not_religious
# 134            89.0               religious
# 135            45.0           not_religious
# 136            85.0               religious
# 137            89.0               religious
# 138            97.0          very_religious
# 139            80.0      slightly_religious
# 140            72.0                 unknown
# 141            93.0               religious
# 142            82.0      slightly_religious
# 143            80.0      slightly_religious
# 144            93.0               religious
# 145            46.0           not_religious
# 146            91.0               religious
# 147            27.0           not_religious
# 148            69.0      slightly_religious
# 149            41.0           not_religious
# 150            59.0      slightly_religious
# 151            79.0      slightly_religious
# 152            30.0           not_religious
# 153            99.0          very_religious
# 154            95.0          very_religious
# 155            88.0               religious

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156 entries, 0 to 155
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country_or_region_id      156 non-null    int64
#  1   country_or_region         156 non-null    object
#  2   happiness_score           156 non-null    float64
#  3   happiness_score_category  156 non-null    category
#  4   peace_index               156 non-null    float64
#  5   peace_index_category      156 non-null    category
#  6   feel_religious            156 non-null    float64
#  7   feel_religious_category   156 non-null    category
# dtypes: category(3), float64(3), int64(1), object(1)
# memory usage: 8.4+ KB

# %% [markdown]
# ## Export the tables as .csv documents

# %%
# happiness.to_csv('/Users/david/Desktop/IronHack/Projects/ETL_project_happiness/data/cleaned_data/happiness_cleaned.csv', index=False)

happiness.to_csv('/Users/david/Desktop/IronHack/Projects/ETL_project_happiness/data/cleaned_data/happiness_cleaned.csv', index=False, float_format='%.2f')

# %% [markdown]
# ## Perform Data Analysis

# %%
# Make a correlation analysis

correlation_matrix = happiness[["happiness_score","peace_index","feel_religious"]].corr()

correlation_matrix
# Out:
#                  happiness_score  peace_index  feel_religious
# happiness_score         1.000000    -0.515868       -0.554974
# peace_index            -0.515868     1.000000        0.420983
# feel_religious         -0.554974     0.420983        1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Create scatter plot with regression line
g = sns.lmplot(x='peace_index', y='happiness_score', data=happiness)

import numpy as np
from sklearn.metrics import r2_score

x = happiness['peace_index']
y = happiness['happiness_score']
y_pred = np.poly1d(np.polyfit(x, y, 1))(x)
r2 = r2_score(y, y_pred)

# Annotate the plot with the R-squared value
g.fig.text(0.15, 0.9, f"R2 = {r2:.2f}", fontsize=12)

plt.show()

# %%
happiness.hist(bins=15, figsize=(25, 20))
# Out:
# array([[<Axes: title={'center': 'country_or_region_id'}>,
#         <Axes: title={'center': 'happiness_score'}>],
#        [<Axes: title={'center': 'peace_index'}>,
#         <Axes: title={'center': 'feel_religious'}>]], dtype=object)

# %%
# Calculate R-squared (R2) value
import numpy as np
from sklearn.metrics import r2_score

x = happiness['peace_index']
y = happiness['happiness_score']
y_pred = np.poly1d(np.polyfit(x, y, 1))(x)
r2 = r2_score(y, y_pred)

# Annotate the plot with the R-squared value
g.fig.text(0.15, 0.9, f"R2 = {r2:.2f}", fontsize=12)

plt.show()

# %%
happiness.dropna(subset=['peace_index', 'happiness_score'], inplace=True)


import matplotlib.pyplot as plt
import statsmodels.api as sm

# Specify the independent and dependent variables
X = happiness['happiness_score']
y = happiness['peace_index']

# Add a constant term to the independent variable(s)
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the coefficients and intercept of the regression line
intercept = model.params[0]
slope = model.params[1]

# Plot the scatter plot of the data points
plt.scatter(happiness['happiness_score'], happiness['peace_index'], label='Data')

# Plot the regression line
plt.plot(happiness['happiness_score'], intercept + slope * happiness['happiness_score'], color='red', label='Regression Line')

# Set plot labels
plt.xlabel('happiness_score')
plt.ylabel('peace_index')
plt.legend()

# Calculate the R-squared value
r_squared = model.rsquared
print(f"R-squared: {r_squared}")

# Show the plot
plt.show()
# Out:
# R-squared: 0.26611988055884495

# %%
happiness.dropna(subset=['happiness_score', 'feel_religious'], inplace=True)


import matplotlib.pyplot as plt
import statsmodels.api as sm

# Specify the independent and dependent variables
X = happiness['feel_religious']
y = happiness['happiness_score']

# Add a constant term to the independent variable(s)
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the coefficients and intercept of the regression line
intercept = model.params[0]
slope = model.params[1]

# Plot the scatter plot of the data points
plt.scatter(happiness['feel_religious'], happiness['happiness_score'], label='Data')

# Plot the regression line
plt.plot(happiness['feel_religious'], intercept + slope * happiness['feel_religious'], color='red', label='Regression Line')

# Set plot labels
plt.xlabel('feel religious')
plt.ylabel('happiness score')
plt.legend()

# Calculate the R-squared value
r_squared = model.rsquared
print(f"R-squared: {r_squared}")

# Show the plot
plt.show()
# Out:
# R-squared: 0.3079961907652774

# %%
happiness.describe()
# Out:
#        country_or_region_id  happiness_score  peace_index  feel_religious
# count            156.000000       156.000000   156.000000      156.000000
# mean              78.500000         5.406987     2.076859       72.339744
# std               45.177428         1.113045     0.500452       23.970276
# min                1.000000         2.850000     1.070000        7.000000
# 25%               39.750000         4.545000     1.772500       54.750000
# 50%               78.500000         5.380000     2.040000       77.000000
# 75%              117.250000         6.182500     2.292500       93.000000
# max              156.000000         7.770000     3.570000      100.000000

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Filter the DataFrame based on the category "very_religious"
filtered_df = happiness[happiness['feel_religious_category'] == 'no_religious']

# Specify the independent and dependent variables
X = filtered_df['peace_index']
y = filtered_df['happiness_score']

# Add a constant term to the independent variable(s)
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the coefficients and intercept of the regression line
intercept = model.params[0]
slope = model.params[1]

# Plot the scatter plot of the data points
plt.scatter(filtered_df['peace_index'], filtered_df['happiness_score'], label='Data')

# Plot the regression line
plt.plot(filtered_df['peace_index'], intercept + slope * filtered_df['peace_index'], color='red', label='Regression Line')

# Set plot labels
plt.xlabel('peace_index')
plt.ylabel('happiness_score')
plt.legend()

# Calculate the R-squared value
r_squared = model.rsquared
print(f"R-squared: {r_squared}")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 15
#      12 X = sm.add_constant(X)
#      14 # Fit the regression model
# ---> 15 model = sm.OLS(y, X).fit()
#      17 # Get the coefficients and intercept of the regression line
#      18 intercept = model.params[0]
#
# File ~/anaconda3/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:906, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     903     msg = ("Weights are not supported in OLS and will be ignored"
#     904            "An exception will be raised in the next version.")
#     905     warnings.warn(msg, ValueWarning)
# --> 906 super(OLS, self).__init__(endog, exog, missing=missing,
#     907                           hasconst=hasconst, **kwargs)
#     908 if "weights" in self._init_keys:
#     909     self._init_keys.remove("weights")
#
# File ~/anaconda3/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:733, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     731 else:
#     732     weights = weights.squeeze()
# --> 733 super(WLS, self).__init__(endog, exog, missing=missing,
#     734                           weights=weights, hasconst=hasconst, **kwargs)
#     735 nobs = self.exog.shape[0]
#     736 weights = self.weights
#
# File ~/anaconda3/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:190, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     189 def __init__(self, endog, exog, **kwargs):
# --> 190     super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File ~/anaconda3/lib/python3.10/site-packages/statsmodels/base/model.py:267, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     266 def __init__(self, endog, exog=None, **kwargs):
# --> 267     super().__init__(endog, exog, **kwargs)
#     268     self.initialize()
#
# File ~/anaconda3/lib/python3.10/site-packages/statsmodels/base/model.py:92, in Model.__init__(self, endog, exog, **kwargs)
#      90 missing = kwargs.pop('missing', 'none')
#      91 hasconst = kwargs.pop('hasconst', None)
# ---> 92 self.data = self._handle_data(endog, exog, missing, hasconst,
#      93                               **kwargs)
#      94 self.k_constant = self.data.k_constant
#      95 self.exog = self.data.exog
#
# File ~/anaconda3/lib/python3.10/site-packages/statsmodels/base/model.py:132, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     131 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 132     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     133     # kwargs arrays could have changed, easier to just attach here
#     134     for key in kwargs:
#
# File ~/anaconda3/lib/python3.10/site-packages/statsmodels/base/data.py:700, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     697     exog = np.asarray(exog)
#     699 klass = handle_data_class_factory(endog, exog)
# --> 700 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     701              **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/statsmodels/base/data.py:88, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      86 self.const_idx = None
#      87 self.k_constant = 0
# ---> 88 self._handle_constant(hasconst)
#      89 self._check_integrity()
#      90 self._cache = {}
#
# File ~/anaconda3/lib/python3.10/site-packages/statsmodels/base/data.py:132, in ModelData._handle_constant(self, hasconst)
#     129 else:
#     130     # detect where the constant is
#     131     check_implicit = False
# --> 132     exog_max = np.max(self.exog, axis=0)
#     133     if not np.isfinite(exog_max).all():
#     134         raise MissingDataError('exog contains inf or nans')
#
# File <__array_function__ internals>:180, in amax(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2793, in amax(a, axis, out, keepdims, initial, where)
#    2677 @array_function_dispatch(_amax_dispatcher)
#    2678 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2679          where=np._NoValue):
#    2680     """
#    2681     Return the maximum of an array or maximum along an axis.
#    2682
#    (...)
#    2791     5
#    2792     """
# -> 2793     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2794                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Filter the DataFrame based on the category "very_safe"
filtered_df = happiness[happiness['peace_index_category'] == 'very_save']

# Specify the independent and dependent variables
X = filtered_df['feel_religious']
y = filtered_df['happiness_score']

# Add a constant term to the independent variable(s)
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the coefficients and intercept of the regression line
intercept = model.params[0]
slope = model.params[1]

# Plot the scatter plot of the data points
plt.scatter(filtered_df['feel_religious'], filtered_df['happiness_score'], label='Data')

# Plot the regression line
plt.plot(filtered_df['feel_religious'], intercept + slope * filtered_df['feel_religious'], color='red', label='Regression Line')

# Set plot labels
plt.xlabel('feel_religious')
plt.ylabel('happiness score')
plt.legend()

# Calculate the R-squared value
r_squared = model.rsquared
print(f"R-squared: {r_squared}")

# Show the plot
plt.show()
